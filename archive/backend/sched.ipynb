# %%
import pandas as pd
import nflreadpy as nfl
from pathlib import Path
import json


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

schedule_df = pd.read_json("./post_schedule.json")
# Out:
# generated_at meta          2026-01-05T02:00:00-08:00
# league                              NFL
# season                             2025
# postseason                          NaN
# Name: generated_at, dtype: object
# 2026-01-05T02:00:00-08:00
# NFL
# 2025
# nan
# timezone meta          America/Los_Angeles
# league                        NFL
# season                       2025
# postseason                    NaN
# Name: timezone, dtype: object
# America/Los_Angeles
# NFL
# 2025
# nan
# source_note meta          Parsed from user-provided bracket/schedule tex...
# league                                                      NFL
# season                                                     2025
# postseason                                                  NaN
# Name: source_note, dtype: object
# Parsed from user-provided bracket/schedule text; TBD slots kept as placeholders.
# NFL
# 2025
# nan
# rounds meta                                                        NaN
# league                                                      NFL
# season                                                     2025
# postseason    [{'name': 'Wild Card', 'games': [{'id': 'AFC-W...
# Name: rounds, dtype: object
# nan
# NFL
# 2025
# [{'name': 'Wild Card', 'games': [{'id': 'AFC-WC-1', 'conference': 'AFC', 'network': 'CBS', 'kickoff_local': '2026-01-11T10:00:00-08:00', 'home': {'seed': 3, 'name': 'Jaguars', 'abbr': 'JAX', 'record': {'wins': 13, 'losses': 4, 'ties': 0}}, 'away': {'seed': 6, 'name': 'Bills', 'abbr': 'BUF', 'record': {'wins': 12, 'losses': 5, 'ties': 0}}, 'notes': []}, {'id': 'AFC-WC-2', 'conference': 'AFC', 'network': 'NBC', 'kickoff_local': '2026-01-11T17:00:00-08:00', 'home': {'seed': 2, 'name': 'Patriots', 'abbr': 'NE', 'record': {'wins': 14, 'losses': 3, 'ties': 0}}, 'away': {'seed': 7, 'name': 'Chargers', 'abbr': 'LAC', 'record': {'wins': 11, 'losses': 6, 'ties': 0}}, 'notes': []}, {'id': 'AFC-WC-3', 'conference': 'AFC', 'network': 'ESPN', 'kickoff_local': '2026-01-12T17:00:00-08:00', 'home': {'seed': 4, 'name': 'Steelers', 'abbr': 'PIT', 'record': {'wins': 10, 'losses': 7, 'ties': 0}}, 'away': {'seed': 5, 'name': 'Texans', 'abbr': 'HOU', 'record': {'wins': 12, 'losses': 5, 'ties': 0}}, 'notes': []}, {'id': 'NFC-WC-1', 'conference': 'NFC', 'network': 'FOX', 'kickoff_local': '2026-01-10T13:30:00-08:00', 'home': {'seed': 4, 'name': 'Panthers', 'abbr': 'CAR', 'record': {'wins': 8, 'losses': 9, 'ties': 0}}, 'away': {'seed': 5, 'name': 'Rams', 'abbr': 'LAR', 'record': {'wins': 12, 'losses': 5, 'ties': 0}}, 'notes': []}, {'id': 'NFC-WC-2', 'conference': 'NFC', 'network': 'Prime Video', 'kickoff_local': '2026-01-10T17:00:00-08:00', 'home': {'seed': 2, 'name': 'Bears', 'abbr': 'CHI', 'record': {'wins': 11, 'losses': 6, 'ties': 0}}, 'away': {'seed': 7, 'name': 'Packers', 'abbr': 'GB', 'record': {'wins': 9, 'losses': 7, 'ties': 1}}, 'notes': []}, {'id': 'NFC-WC-3', 'conference': 'NFC', 'network': 'FOX', 'kickoff_local': '2026-01-11T13:30:00-08:00', 'home': {'seed': 3, 'name': 'Eagles', 'abbr': 'PHI', 'record': {'wins': 11, 'losses': 6, 'ties': 0}}, 'away': {'seed': 6, 'name': '49ers', 'abbr': 'SF', 'record': {'wins': 12, 'losses': 5, 'ties': 0}}, 'notes': []}], 'byes': [{'conference': 'AFC', 'seed': 1, 'name': 'Broncos', 'abbr': 'DEN', 'record': {'wins': 14, 'losses': 3, 'ties': 0}, 'clinched_playoffs': True}, {'conference': 'NFC', 'seed': 1, 'name': 'Seahawks', 'abbr': 'SEA', 'record': {'wins': 14, 'losses': 3, 'ties': 0}, 'clinched_playoffs': True}]}, {'name': 'Divisional', 'games': [{'id': 'AFC-DIV-1', 'conference': 'AFC', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}, {'id': 'AFC-DIV-2', 'conference': 'AFC', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}, {'id': 'NFC-DIV-1', 'conference': 'NFC', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}, {'id': 'NFC-DIV-2', 'conference': 'NFC', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}]}, {'name': 'Conference Championship', 'games': [{'id': 'AFC-CCG', 'conference': 'AFC', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}, {'id': 'NFC-CCG', 'conference': 'NFC', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}]}, {'name': 'Super Bowl', 'games': [{'id': 'SB', 'conference': 'NFL', 'network': None, 'kickoff_local': None, 'home': None, 'away': None, 'notes': ['TBD']}]}]

# %%
logos = pd.read_csv("C:\\Users\\goku\\Documents\\NFL_ML_Predictions\\backend\\team_logos.csv")
print(logos.head())
print(logos.columns)
print(logos.info())
print(logos['team_abbr'].unique())

# %%
for idx, row in logos.items():
    print(idx, '\n', row)

# %%
import logging
from datetime import datetime, timezone, timedelta
import nflreadpy as nfl
import pandas as pd

def get_schedule() -> pd.DataFrame:
    """
    Return the schedule for the "next" NFL week based on the schedule CSV.

    Logic:
      - Resolve schedule path via _find_schedule_path().
      - Normalize season/week + team abbreviations.
      - If 'gameday' is present, interpret as kickoff datetime (UTC-aware).
      - Determine the next slate using the earliest future game; fall back
        to the latest season/week in the file if all games are in the past.
    """
    season = nfl.get_current_season()
    week = nfl.get_current_week()
    df_schedule = nfl.load_schedules().to_pandas()
    logging.info("[Schedule] Loading schedule from: %s", df_schedule)
    dfs = df_schedule.copy()
    now = datetime.now(timezone.utc)
    dfs = dfs[(dfs["season"] == season) & (dfs["week"] == week)]
    return dfs

dfs = get_schedule()
print(dfs)
