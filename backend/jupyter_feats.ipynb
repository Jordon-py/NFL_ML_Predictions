# %%
import pandas as pd 
import nflreadpy as nfl 

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.width = None


load_schedules = nfl.load_schedules()
# print(f'load_schedules : {load_schedules}')
schedules_df = load_schedules.to_pandas()
print(schedules_df.head())
print(schedules_df.columns)
print(schedules_df.info(verbose=True))
print(schedules_df.describe(include='all'))

# %%
team_list = []
teams = schedules_df['home_team'].unique
print(teams)

# %%
teams = nfl.load_teams()
print(teams)

schedules = nfl.load_schedules()
print(schedules)

# %%
print(schedules[-1])
game_stats = nfl.load_team_stats()
game_stats = game_stats.to_pandas()

print(game_stats)

# %%
songlist = [
    "C:\\Users\\goku\\Downloads\\out_batch",
    "C:\\Users\\goku\\Downloads\\peaks",
    "C:\\Users\\goku\\Downloads\\CapCut_7267140873131950085_installer.exe",
    "C:\\Users\\goku\\Downloads\\flstudio_win64_25.2.3.5171.exe",
    "C:\\Users\\goku\\Downloads\\AI-Prompt-Genius-Prompts_2026-01-23T01_17_47.961Z.csv",
    "C:\\Users\\goku\\Downloads\\AI-Prompt-Genius-Prompts_2026-01-23T01_17_47.149Z.json",
    "C:\\Users\\goku\\Downloads\\TARGET_v5_Top Tier_report.md",
    "C:\\Users\\goku\\Downloads\\Vegas - its all love_hifi_report.md",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier_hifi_report.md",
    "C:\\Users\\goku\\Downloads\\Brent Faiyaz - Pistachios [Official Video].mp3",
    "C:\\Users\\goku\\Downloads\\melodic_trap_master_v7_groovelock_pedalboard.py",
    "C:\\Users\\goku\\Downloads\\top_tier.txt",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Teir (iib).wav (1).txt",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Teir (iib).wav (2).txt",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Teir (iib).wav.txt",
    "C:\\Users\\goku\\Downloads\\chef jeff ft vegas - Somebody.wav",
    "C:\\Users\\goku\\Downloads\\chef jeff ft vegas - Somebody_v001.wav",
    "C:\\Users\\goku\\Downloads\\chef jeff ft vegas - Somebody_v002.wav",
    "C:\\Users\\goku\\Downloads\\FM Vegas - Consistent (1).wav",
    "C:\\Users\\goku\\Downloads\\FM Vegas - Consistent.sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\I'm Him (14).wav",
    "C:\\Users\\goku\\Downloads\\Its still love baby (1).wav",
    "C:\\Users\\goku\\Downloads\\Nipssey  (5).wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (1).wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (2).sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (2).wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (3).sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (club).sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (lofi).sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY (neon).sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\SOMEBODY.wav",
    "C:\\Users\\goku\\Downloads\\TLC Shit.sfd_v3.wav",
    "C:\\Users\\goku\\Downloads\\Track1_Mr_Love__RB__Trap_Beat__Wiz_Khalifa_Type__Prod_Tower_Beatz.wav",
    "C:\\Users\\goku\\Downloads\\Vegaas (3).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - its all love_hifinew.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - All Adlibs.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - hook - adlibs.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - hook top tier.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - Imported Track (1).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - Imported Track.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - Voice_Audio (1).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - Voice_Audio (2).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir - Voice_Audio.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (1).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (2).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (3).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (4).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (5).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (6).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (7).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (8).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (9).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (10).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (11).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (12).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (13).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (15).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (16).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (17).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (18).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (19).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir (20).wav",
    "C:\\Users\\goku\\Downloads\\Vegas - top teir.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier_hifi.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier_hifi2.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier_hifinew.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier_Reapercode.wav",
    "C:\\Users\\goku\\Downloads\\Vegas - Top Tier_Reapercode23.wav"
    ]

print(f'songlist : {songlist}')

# %%
def path_to_songs(songlist: list[str]):
    return os.path.join(os.path.dirname(__file__), "songs")
