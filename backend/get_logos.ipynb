# %%
import nflreadpy as nfl

logos = nfl.load_teams()
p_logos=logos.to_pandas()
p_logos.to_csv("team_logos.csv", index=False)

# %%
schedule = nfl.load_schedules(2025)
schedule = schedule.to_pandas()
schedule.to_csv("schedule_2025.csv", index=False)

# %%
import os
import pandas as pd
import pathlib
import dotenv

dotenv.load_dotenv('./.env')
