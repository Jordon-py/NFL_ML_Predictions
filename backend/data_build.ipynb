# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# ---------------------------------------------------------------------
# NFL ML Predictions: Build CSV Datasets Script
# ---------------------------------------------------------------------
# This script builds CSV datasets for NFL machine learning predictions
# using either the 'nflreadpy' or 'nfl_data_py' backend.
# ---------------------------------------------------------------------

df = pd.read_csv('C:\\Users\\goku\\Documents\\NFL_ML_Predictions\\backend\\game_features_20251201.csv')
print(df.head())
print(df.columns)
print(df.shape)
print(df.describe())
print(df.info())
# Out:
#    season  week          game_id home_game_date home_team away_team  \
# 0    2014     1  2014_01_BUF_CHI     2014-09-07       CHI       BUF
# 1    2014     1   2014_01_CAR_TB     2014-09-07        TB       CAR
# 2    2014     1  2014_01_CIN_BAL     2014-09-07       BAL       CIN
# 3    2014     1  2014_01_CLE_PIT     2014-09-07       PIT       CLE
# 4    2014     1   2014_01_GB_SEA     2014-09-04       SEA        GB
#
#    home_points_for  away_points_for  point_diff winner  ...  away_team_NO  \
# 0             20.0             23.0        -3.0    BUF  ...         False
# 1             14.0             20.0        -6.0    CAR  ...         False
# 2             16.0             23.0        -7.0    CIN  ...         False
# 3             30.0             27.0         3.0    PIT  ...         False
# 4             36.0             16.0        20.0    SEA  ...         False
#
#    away_team_NYG  away_team_NYJ  away_team_PHI  away_team_PIT  away_team_SEA  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    away_team_SF  away_team_TB  away_team_TEN  away_team_WAS
# 0         False         False          False          False
# 1         False         False          False          False
# 2         False         False          False          False
# 3         False         False          False          False
# 4         False         False          False          False
#
# [5 rows x 214 columns]
# Index(['season', 'week', 'game_id', 'home_game_date', 'home_team', 'away_team',
#        'home_points_for', 'away_points_for', 'point_diff', 'winner',
#        ...
#        'away_team_NO', 'away_team_NYG', 'away_team_NYJ', 'away_team_PHI',
#        'away_team_PIT', 'away_team_SEA', 'away_team_SF', 'away_team_TB',
#        'away_team_TEN', 'away_team_WAS'],
#       dtype='object', length=214)
# (3282, 214)
#             season         week  home_points_for  away_points_for  \
# count  3282.000000  3282.000000      3203.000000      3203.000000
# mean   2019.573736     9.642596        23.797377        21.821730
# std       3.449759     5.411215        10.121274         9.748223
# min    2014.000000     1.000000         0.000000         0.000000
# 25%    2017.000000     5.000000        17.000000        15.000000
# 50%    2020.000000    10.000000        24.000000        21.000000
# 75%    2023.000000    14.000000        30.000000        28.000000
# max    2025.000000    22.000000        70.000000        59.000000
#
#         point_diff  home_prior_pf_avg_3  home_prior_pa_avg_3  \
# count  3203.000000          3282.000000          3282.000000
# mean      1.975648            22.551645            22.776813
# std      14.265180             6.742520             6.268599
# min     -49.000000             0.000000             0.000000
# 25%      -7.000000            18.000000            18.666667
# 50%       3.000000            22.333333            22.666667
# 75%      10.000000            27.000000            27.000000
# max      52.000000            48.000000            44.333333
#
#        home_prior_win_pct_3  home_prior_off_epa_per_play_3  \
# count           3282.000000                    3282.000000
# mean               0.490047                      -0.005964
# std                0.318478                       0.091065
# min                0.000000                      -0.458784
# 25%                0.333333                      -0.043393
# 50%                0.333333                       0.000000
# 75%                0.666667                       0.025822
# max                1.000000                       0.330238
#
#        home_prior_off_success_rate_3  ...  away_rolling_pa_3  \
# count                    3282.000000  ...        3234.000000
# mean                        0.283940  ...          22.703154
# std                         0.213119  ...           6.092223
# min                         0.000000  ...           3.000000
# 25%                         0.000000  ...          18.333333
# 50%                         0.400908  ...          22.666667
# 75%                         0.449590  ...          26.666667
# max                         0.579120  ...          48.000000
#
#        away_rolling_win_pct_3  away_rolling_pf_5  away_rolling_pa_5  \
# count             3234.000000        3266.000000        3266.000000
# mean                 0.503762          22.842621          22.714227
# std                  0.313287           5.575551           4.931831
# min                  0.000000           3.000000           0.000000
# 25%                  0.333333          18.800000          19.350000
# 50%                  0.666667          22.800000          22.600000
# 75%                  0.666667          26.600000          26.000000
# max                  1.000000          41.000000          40.400000
#
#        away_rolling_win_pct_5  away_rolling_pf_10  away_rolling_pa_10  \
# count             3266.000000         3266.000000         3266.000000
# mean                 0.500219           22.812505           22.789215
# std                  0.264530            4.610677            3.848753
# min                  0.000000            6.000000            6.000000
# 25%                  0.400000           19.600000           20.000000
# 50%                  0.600000           22.633333           22.700000
# 75%                  0.600000           26.000000           25.400000
# max                  1.000000           37.000000           39.666667
#
#        away_rolling_win_pct_10  home_qb_completion_pct  away_qb_completion_pct
# count              3266.000000             3097.000000             3095.000000
# mean                  0.499231                0.648167                0.635074
# std                   0.212914                0.093325                0.094375
# min                   0.000000                0.285714                0.300000
# 25%                   0.375000                0.586207                0.574271
# 50%                   0.500000                0.648649                0.636364
# 75%                   0.700000                0.714286                0.697674
# max                   1.000000                1.000000                0.956522
#
# [8 rows x 143 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Columns: 214 entries, season to away_team_WAS
# dtypes: bool(65), float64(137), int64(6), object(6)
# memory usage: 3.9+ MB
# None
