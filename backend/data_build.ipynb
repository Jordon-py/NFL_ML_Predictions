# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# ---------------------------------------------------------------------
# NFL ML Predictions: Build CSV Datasets Script
# ---------------------------------------------------------------------
# This script builds CSV datasets for NFL machine learning predictions
# using either the 'nflreadpy' or 'nfl_data_py' backend.
# ---------------------------------------------------------------------

df = pd.read_csv('C:\\Users\\goku\\Documents\\NFL_ML_Predictions\\backend\\game_features_2014_2025.csv')
print(df.head())
print(df.columns)
print(df.shape)
print(df.describe())
print(df.info())
