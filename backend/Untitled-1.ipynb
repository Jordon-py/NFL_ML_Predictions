# %%
import pandas as pd
from sklearn.cluster import AffinityPropagation
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 1000)


# 1. Load the dataset prep for clustering
# Ensure path compatibility
df = pd.read_csv('backend/game_features_2014_2025.csv')
print(f"Columns: {df.columns.tolist()}")
df.info(verbose=True)

# Drop rows with missing results (future games) to avoid NaN errors
df = df.dropna(axis=0, subset=['home_win'])

# Convert home_win to binary (0/1)
# .astype(int) efficiently converts boolean True/False to 1/0
df['home_win'] = df['home_win'].astype(int)

df = df.convert_dtypes()
y = df['home_win'].to_numpy()
X = df.select_dtypes(include=[np.number]).drop(columns=['home_win']).to_numpy()
"""
# Get metrics (descriptive statistics)
print("Data Metrics:")
print(df.describe())
df.describe().to_csv('backend/data_metrics_full.csv')
df.describe().to_json('backend/data_metrics_full.json')

Data_Metrics = df.describe().to_dict()
pd.DataFrame(Data_Metrics).to_csv('backend/data_metrics.csv')
df['home_win'] = df['home_win'].astype(int)

print(f'DATA home_win values: {df["home_win"].unique()}')
print(f'Data Types sample: {df.dtypes.head()}')
"""

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(nrows=3074, ncols=163, figsize=(15, 15))

axs[0, 0].scatter(X[:, 0], X[:, 1], c=y)
axs[0, 0].set_title("Mixture of Gaussian Blobs")
print(f"DATA X shape: {X.shape}, y shape: {y.shape}")
