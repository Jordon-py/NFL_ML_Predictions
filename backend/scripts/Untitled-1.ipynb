# %%
import pandas as pd
import numpy as np

df = pd.read_csv('test_results_2025_week_1.csv')
df2 = pd.read_csv('nfl_data_sorted.csv')

print(df.shape)
print(df2.shape)
print(df2.columns)
# Out:
# (16, 5)
# (3026, 22)
# Index(['season', 'week', 'game_id', 'game_date', 'home_team', 'away_team',
#        'home_points_for', 'away_points_for', 'point_diff', 'winner',
#        'home_prior_pa_avg_3', 'home_prior_pa_avg_5', 'home_prior_pf_avg_3',
#        'home_prior_pf_avg_5', 'home_prior_win_pct_3', 'home_prior_win_pct_5',
#        'away_prior_pa_avg_3', 'away_prior_pa_avg_5', 'away_prior_pf_avg_3',
#        'away_prior_pf_avg_5', 'away_prior_win_pct_3', 'away_prior_win_pct_5'],
#       dtype='object')

# %%
# Filter for 2025, week 1
week_1_2025_df = df2[(df2['season'] == 2025) & (df2['week'] == 1)]

# Select the desired columns from the filtered DataFrame
if not week_1_2025_df.empty:
    df3 = week_1_2025_df[['home_team', 'away_team', 'home_points_for', 'away_points_for', 'point_diff', 'winner']]

# %% [markdown]
# print(df.head(16))
# print(df3.head(16))
